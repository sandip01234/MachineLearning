# %% [markdown]
# <a href="https://colab.research.google.com/github/sandip01234/MachineLearning/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# %%
newdata = {
    "calories" :[100,200,300,400],
    "duration" :[50,40,45,50]

}
newdata
# Out:
# {'calories': [100, 200, 300, 400], 'duration': [50, 40, 45, 50]}

# %%
df=pd.DataFrame(newdata)
df
# Out:
#    calories  duration
# 0       100        50
# 1       200        40
# 2       300        45
# 3       400        50

# %%
df=pd.DataFrame(newdata,index=["day1","day2","day3","day4"])
df
# Out:
#       calories  duration
# day1       100        50
# day2       200        40
# day3       300        45
# day4       400        50

# %%
print(df.loc[["day1","day2"]])
# Out:
#       calories  duration
# day1       100        50
# day2       200        40

# %% [markdown]
# # Data Cleaning
# ## empty cell
# ## wrong data
# ## duplicates

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataset(1).csv")
df
# Out:
#     Duration  Date        Pulse  Maxpulse  Calories  Unnamed: 5
# 0          0    60  2020/12/01'       110       130       409.1
# 1          1    60  2020/12/02'       117       145       479.0
# 2          2    60  2020/12/03'       103       135       340.0
# 3          3    45  2020/12/04'       109       175       282.4
# 4          4    45  2020/12/05'       117       148       406.0
# 5          5    60  2020/12/06'       102       127       300.0
# 6          6    60  2020/12/07'       110       136       374.0
# 7          7   450  2020/12/08'       104       134       253.3
# 8          8    30  2020/12/09'       109       133       195.1
# 9          9    60  2020/12/10'        98       124       269.0
# 10        10    60  2020/12/11'       103       147       329.3
# 11        11    60  2020/12/12'       100       120       250.7
# 12        12    60  2020/12/12'       100       120       250.7
# 13        13    60  2020/12/13'       106       128       345.3
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/pandas_dataset.csv")
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
df.head(5)
# Out:
#    Duration         Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01'    110       130     409.1
# 1        60  2020/12/02'    117       145     479.0
# 2        60  2020/12/03'    103       135     340.0
# 3        45  2020/12/04'    109       175     282.4
# 4        45  2020/12/05'    117       148     406.0

# %%
df["Date"]=df["Date"].replace("'", "" , regex=True)
df.head(5)
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01    110       130     409.1
# 1        60  2020/12/02    117       145     479.0
# 2        60  2020/12/03    103       135     340.0
# 3        45  2020/12/04    109       175     282.4
# 4        45  2020/12/05    117       148     406.0

# %%
#return a dataset with no empty cells
#df.dropne() will remove empty cells but will not change the dataFrame
#If we want data frame to bve change, use inplace =true
new_df = df.dropna()
new_df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
#another way of handling the null values is by replacing null value with somevalue
df_new2 = df.fillna(130)
df_new2
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
#fill specific column's null value
df_new3 = df["Calories"].fillna("acharya")
df_new3
# Out:
# 0       409.1
# 1       479.0
# 2       340.0
# 3       282.4
# 4       406.0
# 5       300.0
# 6       374.0
# 7       253.3
# 8       195.1
# 9       269.0
# 10      329.3
# 11      250.7
# 12      250.7
# 13      345.3
# 14      379.3
# 15      275.0
# 16      215.2
# 17      300.0
# 18    acharya
# 19      323.0
# 20      243.0
# 21      364.2
# 22      282.0
# 23      300.0
# 24      246.0
# 25      334.5
# 26      250.0
# 27      241.0
# 28    acharya
# 29      280.0
# 30      380.3
# 31      243.0
# Name: Calories, dtype: object

# %%
#fill null values with mean, median or mode
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/pandas_dataset.csv")
df["Date"]=df["Date"].replace("'", "" , regex=True)
df.dropna()
x = df["Calories"].mean()
df["Calories"].fillna(x, inplace = True)
df
# Out:
# <ipython-input-34-6542178a311f>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(x, inplace = True)
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130    409.10
# 1         60  2020/12/02    117       145    479.00
# 2         60  2020/12/03    103       135    340.00
# 3         45  2020/12/04    109       175    282.40
# 4         45  2020/12/05    117       148    406.00
# 5         60  2020/12/06    102       127    300.00
# ...
